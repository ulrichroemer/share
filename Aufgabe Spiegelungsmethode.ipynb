# %%
# %run Funktionen.ipynb    # lade Funktionen zum Zeichnen der Loesung

# lade Aufgabenstellung
from IPython.display import IFrame   
IFrame("Aufgabe.pdf", width=520, height=420)
# Out:
#         <iframe
#             width="520"
#             height="420"
#             src="Aufgabe.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Parameter der Anordnung
display(R_widget)
display(s1_widget)
# Out:
# FloatSlider(value=0.2, description='R:', max=0.5, min=0.1)
# FloatSlider(value=1.0, description='s1:', max=1.0, min=0.6)

# %%
# Parameterwerte
R = R_widget.value
s1 = s1_widget.value

# Lösungswerte hier eingeben
Q2 = ???
s2 = ???

zeichneSpiegelladung(Q1,Q2,s1,s2,R)
